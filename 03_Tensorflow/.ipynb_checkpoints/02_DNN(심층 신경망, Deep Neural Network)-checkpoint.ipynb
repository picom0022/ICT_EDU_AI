# %% [markdown]
# # 02.DNN(심층 신경망, Deep Neural Network)
#
# >  집 값 예측하기

# %%
from IPython.display import Image

Image('img/day01_02.png', width=600)

# %%
Image('img/day01_03.png', width=600)

# %%
Image('img/day01_04.png', width=600)

# %%
Image('img/day01_05.png', width=600)

# %%
import pandas as pd
import tensorflow as tf 
import matplotlib.pyplot as plt
import seaborn as sns
from time import time

from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
# 하이퍼 파라미터
MY_EPOCH = 500
MY_BATCH = 64

# %% [markdown]
# ### 데이터 수집

# %%
raw = pd.read_csv('data/housing.csv')
raw
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  LSTAT  MEDV
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3   4.98  24.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8   9.14  21.6
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8   4.03  34.7
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7   2.94  33.4
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7   5.33  36.2
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...      ...    ...   ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0   9.67  22.4
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0   9.08  20.6
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0   5.64  23.9
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0   6.48  22.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0   7.88  11.9
#
# [506 rows x 13 columns]

# %%
# from sklearn.datasets import fetch_openml
# boston = fetch_openml(name="boston", version=1, as_frame=True)
# boston

# %% [markdown]
# ### 2. 정규화 처리

# %%
Image("img/day01_06.png",width=600)

# %%
# z-점수 정규화의 결과는 numpy의 n차원 행렬 방정식
scaler = StandardScaler()
z_data = scaler.fit_transform(raw)
print(z_data)
print(type(z_data))
# Out:
# [[-0.41978194  0.28482986 -1.2879095  ... -1.45900038 -1.0755623
#    0.15968566]
#  [-0.41733926 -0.48772236 -0.59338101 ... -0.30309415 -0.49243937
#   -0.10152429]
#  [-0.41734159 -0.48772236 -0.59338101 ... -0.30309415 -1.2087274
#    1.32424667]
#  ...
#  [-0.41344658 -0.48772236  0.11573841 ...  1.17646583 -0.98304761
#    0.14880191]
#  [-0.40776407 -0.48772236  0.11573841 ...  1.17646583 -0.86530163
#   -0.0579893 ]
#  [-0.41500016 -0.48772236  0.11573841 ...  1.17646583 -0.66905833
#   -1.15724782]]
# <class 'numpy.ndarray'>

# %%
z_data = pd.DataFrame(z_data,columns=raw.columns)
z_data
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX  ...       RAD       TAX   PTRATIO     LSTAT      MEDV
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  ... -0.982843 -0.666608 -1.459000 -1.075562  0.159686
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  ... -0.867883 -0.987329 -0.303094 -0.492439 -0.101524
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  ... -0.867883 -0.987329 -0.303094 -1.208727  1.324247
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  ... -0.752922 -1.106115  0.113032 -1.361517  1.182758
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  ... -0.752922 -1.106115  0.113032 -1.026501  1.487503
# ..        ...       ...       ...       ...       ...  ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738 -0.272599  0.158124  ... -0.982843 -0.803212  1.176466 -0.418147 -0.014454
# 502 -0.415249 -0.487722  0.115738 -0.272599  0.158124  ... -0.982843 -0.803212  1.176466 -0.500850 -0.210362
# 503 -0.413447 -0.487722  0.115738 -0.272599  0.158124  ... -0.982843 -0.803212  1.176466 -0.983048  0.148802
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  ... -0.982843 -0.803212  1.176466 -0.865302 -0.057989
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124  ... -0.982843 -0.803212  1.176466 -0.669058 -1.157248
#
# [506 rows x 13 columns]

# %% [markdown]
# ### 학습용과 평가용 분리하기

# %%
# test_size = 0.3 랜덤 30% 추출
X_train, X_test, y_train, y_test = train_test_split(z_data.iloc[:,:12],z_data.iloc[:,12:], test_size=0.3, random_state=42)

print("학습용 입력 데이터: ",X_train.shape)
print("학습용 출력 데이터: ",y_train.shape)
print("평가용 입력 데이터: ",X_test.shape)
print("평가용 출력 데이터: ",y_test.shape)
# Out:
# 학습용 입력 데이터:  (354, 12)
# 학습용 출력 데이터:  (354, 1)
# 평가용 입력 데이터:  (152, 12)
# 평가용 출력 데이터:  (152, 1)

# %%
sns.boxenplot(data=z_data, palette='dark')
plt.show()

# %%
Image("img/day01_08.png")

# %% [markdown]
# ### (12 * 200) +200 = 2600개 (덴스 연결 1:1 완전 연결)

# %%
Image('img/day01_09.png', width=600)

# %% [markdown]
# ### 4. 인공 신경망 구현

# %%
## keras DNN 구현
model = Sequential()
input = X_train.shape[1]

model.add(Dense(200, activation='relu'))
model.add(Dense(1000, activation='relu'))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
